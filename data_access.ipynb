# %%
from astroquery.gaia import Gaia
tables = Gaia.load_tables(only_names=True)
for table in (tables):
    print (table.get_qualified_name())
# Out:
# Created TAP+ (v1.0.1) - Connection:
# 	Host: gea.esac.esa.int
# 	Use HTTPS: False
# 	Port: 80
# 	SSL Port: 443
# Retrieving tables...
# Parsing tables...
# Done.
# public.public.dual
# public.public.hipparcos
# public.public.hipparcos_newreduction
# public.public.hubble_sc
# public.public.igsl_source
# public.public.igsl_source_catalog_ids
# public.public.tycho2
# tap_schema.tap_schema.columns
# tap_schema.tap_schema.key_columns
# tap_schema.tap_schema.keys
# tap_schema.tap_schema.schemas
# tap_schema.tap_schema.tables
# gaiadr1.gaiadr1.aux_qso_icrf2_match
# gaiadr1.gaiadr1.ext_phot_zero_point
# gaiadr1.gaiadr1.allwise_best_neighbour
# gaiadr1.gaiadr1.allwise_neighbourhood
# gaiadr1.gaiadr1.gsc23_best_neighbour
# gaiadr1.gaiadr1.gsc23_neighbourhood
# gaiadr1.gaiadr1.ppmxl_best_neighbour
# gaiadr1.gaiadr1.ppmxl_neighbourhood
# gaiadr1.gaiadr1.sdss_dr9_best_neighbour
# gaiadr1.gaiadr1.sdss_dr9_neighbourhood
# gaiadr1.gaiadr1.tmass_best_neighbour
# gaiadr1.gaiadr1.tmass_neighbourhood
# ...

# %%
table = Gaia.load_table('gaiadr2.gaia_source')
print(table)
# Out:
# Retrieving table 'gaiadr2.gaia_source'
# Parsing table 'gaiadr2.gaia_source'...
# Done.
# TAP Table name: gaiadr2.gaiadr2.gaia_source
# Description: This table has an entry for every Gaia observed source as listed in the
# Main Database accumulating catalogue version from which the catalogue
# release has been generated. It contains the basic source parameters,
# that is only final data (no epoch data) and no spectra (neither final
# nor epoch).
# Num. columns: 96

# %%
for col in table.get_columns():
    print(col.get_name(),col)
# Out:
# solution_id TAP Column name: solution_id
# Description: Solution Identifier
# Unit:
# Ucd: meta.version
# Utype:
# DataType: BIGINT
# ArraySize: None
# Flag: indexed
# designation TAP Column name: designation
# Description: Unique source designation (unique across all Data Releases)
# Unit:
# Ucd: meta.id;meta.main
# Utype:
# DataType: VARCHAR
# ArraySize: None
# Flag: indexed
# source_id TAP Column name: source_id
# Description: Unique source identifier (unique within a particular Data Release)
# Unit:
# Ucd: meta.id
# Utype:
# DataType: BIGINT
# ArraySize: None
# Flag: primary
# random_index TAP Column name: random_index
# Description: Random index used to select subsets
# Unit:
# Ucd: meta.code
# Utype:
# DataType: BIGINT
# ArraySize: None
# Flag: indexed
# ref_epoch TAP Column name: ref_epoch
# Description: Reference epoch
# Unit: yr
# Ucd: meta.ref;time.epoch
# Utype:
# DataType: DOUBLE
# ArraySize: None
# Flag: indexed
# ra TAP Column name: ra
# Description: Right ascension
# ...

# %%
col.get_array_size
